# %% [markdown]
# ### NLP of news API sentiment analysis. Disney Ex.

# %%
from iexfinance.stocks import Stock
import pandas as pd
from newsapi.newsapi_client import NewsApiClient
from datetime import date, datetime, timedelta
import os
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pickle
analyzer = SentimentIntensityAnalyzer()
nltk.download('vader_lexicon')
from pathlib import Path
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Richard\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
newsapi = NewsApiClient(api_key=os.environ["NEWS_API"])
pickle.dump(newsapi,open('newsapi.pickle','wb'))
current_date = date.today()
past_date = date.today() - timedelta(days=30)

# %%
def get_headlines(keyword):
    all_headlines = []  #empty list for all headlines
    all_dates = [] #empyt list for all dates
    date = current_date #today's date
    print(f"Fetching news about '{keyword}'") #prints single string of function starting
    print("*" * 30) #creating a line of stars for readability
    while date > past_date: #establishes length of dates being pulled by for the lenght of the difference between today and past_date 
        print(f"retrieving news from: {date}")#printing string for loop readability  
        articles = newsapi.get_everything(   #pulling articles through API
            q=keyword,
            from_param=str(date),
            to=str(date),
            language="en",
            sort_by="relevancy",
            page=1,
        )
        headlines = []
        for i in range(0, len(articles["articles"])):
            
            #pulling the content part of the dict
            headlines.append(articles["articles"][i]["content"])
        all_headlines.append(headlines)
        all_dates.append(date)
        date = date - timedelta(days=1) #moving through the days            
    return all_headlines, all_dates

# %%
company_headlines, dates = get_headlines('disney')
# Out:
# Fetching news about 'disney'
# ******************************
# retrieving news from: 2020-04-11
# retrieving news from: 2020-04-10
# retrieving news from: 2020-04-09
# retrieving news from: 2020-04-08
# retrieving news from: 2020-04-07
# retrieving news from: 2020-04-06
# retrieving news from: 2020-04-05
# retrieving news from: 2020-04-04
# retrieving news from: 2020-04-03
# retrieving news from: 2020-04-02
# retrieving news from: 2020-04-01
# retrieving news from: 2020-03-31
# retrieving news from: 2020-03-30
# retrieving news from: 2020-03-29
# retrieving news from: 2020-03-28
# retrieving news from: 2020-03-27
# retrieving news from: 2020-03-26
# retrieving news from: 2020-03-25
# retrieving news from: 2020-03-24
# retrieving news from: 2020-03-23
# retrieving news from: 2020-03-22
# retrieving news from: 2020-03-21
# retrieving news from: 2020-03-20
# retrieving news from: 2020-03-19
# retrieving news from: 2020-03-18
# retrieving news from: 2020-03-17
# retrieving news from: 2020-03-16
# retrieving news from: 2020-03-15
# retrieving news from: 2020-03-14
# retrieving news from: 2020-03-13

# %%
company_df = pd.DataFrame(company_headlines)
company_df.index = pd.to_datetime(dates)
company_df.head()
# Out:
#                                                             0  \
# 2020-04-11  @juliepoolie20\r\nThe starting place for some ...
# 2020-04-10  Ahead of last November's launch of the Apple T...
# 2020-04-09  Walt Disney Co. reported more than 50 million ...
# 2020-04-08  The Walt Disney Company just announced that it...
# 2020-04-07  If you watch a lot of Disney+ on Windows or ma...
#
#                                                             1  \
# 2020-04-11  "This movie is evil, driveling, PC garbage. Ro...
# 2020-04-10  Samantha Barks and Stephanie McKeon have been ...
# 2020-04-09  The Walt Disney Company has managed to amass 5...
# 2020-04-08  We finally know just about how many subscriber...
# 2020-04-07  However, Screen Pass doesn't work with all mov...
#
#                                                             2  \
# 2020-04-11  If you're one of the many who's wondering why ...
# 2020-04-10  Apple TV+, the tech giants foray into the stre...
# 2020-04-09  Catching up with Homer, Marge, Bart, Lisa, and...
# 2020-04-08  <li>Tooning Out the News, CBS All Access, 3 AM...
# 2020-04-07  Owners of Vizio’s smart TVs already had access...
#
#                                                             3  \
# 2020-04-11  According to reports, Disney‘s animated 1973 c...
# 2020-04-10                      Do you know your Disney ABCs?
# 2020-04-09  Disney's popular streaming entertainment servi...
# 2020-04-08  Five months after launching, and with millions...
# 2020-04-07  Last month, it was reported that digital locke...
#
#                                                             4  \
# 2020-04-11  One stock on many people's radar these days is...
# 2020-04-10  (Courtesy of JRE Clips)\r\nUFC commentator Joe...
# 2020-04-09                                               None
# 2020-04-08  Disney's streaming service Disney Plus is the ...
# 2020-04-07  I love a good community effort, and give all t...
#
#                                                             5  \
# 2020-04-11  Caroline Polachek has released the instrumenta...
# 2020-04-10  Walt Disney Studios\r\nFor the most up-to-date...
# 2020-04-09  All the Disney Parks are closed* but that does...
# 2020-04-08  Disney today announced that its Disney+ stream...
# 2020-04-07  As worldwide quarantine measures mitigate the ...
#
#                                                             6  \
# 2020-04-11  <ul><li>Disney has delayed the premiere of all...
# 2020-04-10  Robin Hood, otherwise known as the animated mo...
# 2020-04-09  By now we all know that lockdowns suck. Thankf...
# 2020-04-08  Disney Plus streams movies and shows from Disn...
# 2020-04-07  Quibi, the (mostly) mobile-only streaming serv...
#
#                                                             7  \
# 2020-04-11  Disney(NYSE:DIS) surprised investors when it a...
# 2020-04-10  Disney Plus documentaries may not be the first...
# 2020-04-09  TL;DR: A three-year subscription to CyberGhost...
# 2020-04-08  Disney+ continues to grow its subscriber base,...
# 2020-04-07  People are filling their stay-at-home days wit...
#
#                                                             8  \
# 2020-04-11  Video streaming services have been around for ...
# 2020-04-10  The Beauty and the Beast live-action prequel c...
# 2020-04-09  Disney+ already has 50 million paying subscrib...
# 2020-04-08  For the most up-to-date news and information a...
# 2020-04-07  If you're tired of your current home entertain...
#
#                                                             9  \
# 2020-04-11  Diane Rodriguez, whose career was immersed in ...
# 2020-04-10  The recent history of Disney as a film studio ...
# 2020-04-09  Director and actor Wes Tank drops some Dr. Seu...
# 2020-04-08  Sure, you could be watching an awful lot of Th...
# 2020-04-07                                               None
#
#                                                            10  \
# 2020-04-11  Cast members at Walt Disney World Resort are k...
# 2020-04-10  Disney’s latest “live-action” remake of one of...
# 2020-04-09  Shares of Walt Disney Co. rallied Thursday, af...
# 2020-04-08  Disney today announced that its Disney+ stream...
# 2020-04-07  This article is part of a series tracking the ...
#
#                                                            11  \
# 2020-04-11  If you're one of the many who's wondering why ...
# 2020-04-10  On March 11, Disney announced that its highly-...
# 2020-04-09  TL;DR: Enjoy all forms of entertainment with a...
# 2020-04-08  Disney has announced a massive milestone for i...
# 2020-04-07  With movie theaters shut down for the time bei...
#
#                                                            12  \
# 2020-04-11  You’re stuck at home and in desperate need of ...
# 2020-04-10  Dove Cameron paints a detailed picture of how ...
# 2020-04-09  If you're sitting back wishing your TV at home...
# 2020-04-08  Bless the hearts of the corporate overlords at...
# 2020-04-07          BuzzFeed HomeSitemap© 2020 BuzzFeed, Inc.
#
#                                                            13  \
# 2020-04-11  Disney (DIS), like every other company out the...
# 2020-04-10  Disney+ subscribers, mark your calendars: It’s...
# 2020-04-09       "Yo, (character name), he was just fourteen"
# 2020-04-08                                               None
# 2020-04-07  Prince Harry and Meghan Markle revealed the na...
#
#                                                            14  \
# 2020-04-11  If there is anything Im willing to thank coron...
# 2020-04-10  For the first time in history, all Disney them...
# 2020-04-09  UFC 249 was canceled Thursday after ESPN and p...
# 2020-04-08  The Walt Disney Company just announced that it...
# 2020-04-07  Hello from the home front and welcome to this ...
#
#                                                            15  \
# 2020-04-11                                               None
# 2020-04-10  Its a common jokethat is also, from anecdotal ...
# 2020-04-09  Crime, poverty, gentrification...Captain Hook?...
# 2020-04-08  Walt Disney Co.’s five-month-old Disney+ servi...
# 2020-04-07  Fans of Disney's Frozen should keep an eye on ...
#
#                                                            16  \
# 2020-04-11  It is with deepest pride and greatest pleasure...
# 2020-04-10  Looking for the ultimate comfort food? Now you...
# 2020-04-09  U.S. equity markets surged Thursday morning af...
# 2020-04-08  We finally know just about how many subscriber...
# 2020-04-07  You could drive around in todays Nice Price or...
#
#                                                            17  \
# 2020-04-11  This Earth Month, we look to nature to bring h...
# 2020-04-10  Theme park operators in Florida have been conc...
# 2020-04-09  Disney+ has officially reached 50 million subs...
# 2020-04-08  Doogie Howser, MD launched the career of Neil ...
# 2020-04-07  Everyone is learning how to be more productive...
#
#                                                            18  \
# 2020-04-11  If you're one of the many who's wondering why ...
# 2020-04-10                                               None
# 2020-04-09  Disney+ has passed a major milestone. Followin...
# 2020-04-08  In the year 2052, when Disney has finally comp...
# 2020-04-07  Once this pandemic nightmare is over, a lot of...
#
#                                                            19
# 2020-04-11  We’re dropping in today with some juicy tips o...
# 2020-04-10  Christina Aguilera, Kristin Chenoweth and Luke...
# 2020-04-09  Disney\r\nLouis might have the body of a preda...
# 2020-04-08  “Doogie Howser, M.D.” is getting a female-fron...
# 2020-04-07  from the copyright-yo-psa dept\r\nLots of famo...

# %%
concatinated_list = []
i = 0
while i < len(disney_df):
    date = disney_df.index[i]
    daily_data = disney_df.iloc[i,:].dropna().to_list()
    daily_data = "".join(daily_data)
    concatinated_list.append({"Date":date,
                              "articles":daily_data
                              })
    
    i = i + 1

# %%
disney_df = pd.DataFrame(concatinated_list)

disney_df.head(30)
# Out:
#          Date                                           articles
# 0  2020-04-11  @juliepoolie20\r\nThe starting place for some ...
# 1  2020-04-10  Ahead of last November's launch of the Apple T...
# 2  2020-04-09  Walt Disney Co. reported more than 50 million ...
# 3  2020-04-08  The Walt Disney Company just announced that it...
# 4  2020-04-07  If you watch a lot of Disney+ on Windows or ma...
# 5  2020-04-06  The unusual-looking cylindrical Shield TV has ...
# 6  2020-04-05  Selena Gomez is speaking out about being bipol...
# 7  2020-04-04  Artemis Fowl, based on the first book of the A...
# 8  2020-04-03  With movie theaters largely closed due to the ...
# 9  2020-04-02  Nearly six months after Disney Plus launched\r...
# 10 2020-04-01  Its April 1st, which means a ton of new conten...
# 11 2020-03-31  Amazon faces worker complaints over its respon...
# 12 2020-03-30  Looking for something to watch tonight?\r\nLas...
# 13 2020-03-29  New York (CNN Business)Disneyland in Californi...
# 14 2020-03-28  With Disneyland and Disney World closed indefi...
# 15 2020-03-27  The massive amount of premium content on Disne...
# 16 2020-03-26  Disney's streaming service, Disney Plus, is th...
# 17 2020-03-25  TL;DR: A three-year subscription to NordVPN is...
# 18 2020-03-24  Disney+ launches in seven European countries, ...
# 19 2020-03-23  If you decide to take advantage, keep in mind ...
# 20 2020-03-22  Since movie theaters all over are shutting dow...
# 21 2020-03-21  TL;DR: A 12-month subscription to Disney+ is a...
# 22 2020-03-20  Disney said on Friday that it is postponing th...
# 23 2020-03-19  If your streaming queue is starting to look a ...
# 24 2020-03-18  It was supposed to launch alongside WarnerMedi...
# 25 2020-03-17  Following several other movies, including Mula...
# 26 2020-03-16  TL;DR: An annual Disney+ subscription is avail...
# 27 2020-03-15  TV and film productions are being put on hold,...
# 28 2020-03-14  The press release didn't indicate exactly what...
# 29 2020-03-13  Mulan is not going to become a Disney Plus ori...

# %%
def get_sentiment(dataframe):
# list of sentiment objects observed
    df_sentiments = []
    i = 0 
    # for rows in df: # the next time you put a for-loop outside of a try fn there will be a muckduck
    # for loops are used for interating through one object ie. for every item in list 
    # while loops can be used for interating through multiple objects on the same index ie. 1st item in ...for 2nd item in... for 3rd item in.. 


    while i < len(dataframe["articles"]): # if we did len of df, then it would be the length of columns
                                  # by doing len of df[col], then its length of rows

        # to get values for the sentiment parameters
        text = dataframe["articles"][i] 
        date = df["Date"][i]

        # activate sentiment analysis
        sentiment = analyzer.polarity_scores(text)  ## Attribute Error is applied for NoneTypes in 
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]

        # append results of sentiment analysis per row of sentiment parameters df
        df_sentiments.append({
                "text": text,
                "date": date,
                "compound": compound,
                "positive": pos,
                "negative": neg,
                "neutral": neu

            })



        i += 1

    # Create DataFrame
    final_df = pd.DataFrame(df_sentiments)

    # Reorder DataFrame columns
    cols = ["date", "text", "compound", "positive", "negative", "neutral"]
    final_list = final_df[cols]

    return final_list

# %%
disney_sentiment = get_sentiment(disney_df)

# %%
disney_sentiment = pd.DataFrame(disney_sentiment)
disney_sentiment.to_csv("disney_sentiment.csv", index=False)

# %%
disney_sentiment.head(30)
# Out:
#          date                                               text  compound  \
# 0  2020-04-11  @juliepoolie20\r\nThe starting place for some ...    0.9980
# 1  2020-04-10  Ahead of last November's launch of the Apple T...    0.9957
# 2  2020-04-09  Walt Disney Co. reported more than 50 million ...    0.9881
# 3  2020-04-08  The Walt Disney Company just announced that it...    0.9724
# 4  2020-04-07  If you watch a lot of Disney+ on Windows or ma...    0.9745
# 5  2020-04-06  The unusual-looking cylindrical Shield TV has ...    0.9973
# 6  2020-04-05  Selena Gomez is speaking out about being bipol...    0.9970
# 7  2020-04-04  Artemis Fowl, based on the first book of the A...    0.9975
# 8  2020-04-03  With movie theaters largely closed due to the ...    0.9963
# 9  2020-04-02  Nearly six months after Disney Plus launched\r...    0.9963
# 10 2020-04-01  Its April 1st, which means a ton of new conten...    0.9927
# 11 2020-03-31  Amazon faces worker complaints over its respon...    0.9961
# 12 2020-03-30  Looking for something to watch tonight?\r\nLas...    0.7220
# 13 2020-03-29  New York (CNN Business)Disneyland in Californi...    0.9836
# 14 2020-03-28  With Disneyland and Disney World closed indefi...    0.9914
# 15 2020-03-27  The massive amount of premium content on Disne...    0.9948
# 16 2020-03-26  Disney's streaming service, Disney Plus, is th...    0.3439
# 17 2020-03-25  TL;DR: A three-year subscription to NordVPN is...    0.9952
# 18 2020-03-24  Disney+ launches in seven European countries, ...    0.9942
# 19 2020-03-23  If you decide to take advantage, keep in mind ...    0.9500
# 20 2020-03-22  Since movie theaters all over are shutting dow...    0.9932
# 21 2020-03-21  TL;DR: A 12-month subscription to Disney+ is a...    0.9459
# 22 2020-03-20  Disney said on Friday that it is postponing th...    0.8507
# 23 2020-03-19  If your streaming queue is starting to look a ...   -0.8074
# 24 2020-03-18  It was supposed to launch alongside WarnerMedi...    0.9715
# 25 2020-03-17  Following several other movies, including Mula...    0.9963
# 26 2020-03-16  TL;DR: An annual Disney+ subscription is avail...    0.9832
# 27 2020-03-15  TV and film productions are being put on hold,...   -0.9928
# 28 2020-03-14  The press release didn't indicate exactly what...    0.2598
# 29 2020-03-13  Mulan is not going to become a Disney Plus ori...   -0.4406
#
#     positive  negative  neutral
# 0      0.136     0.030    0.834
# 1      0.101     0.025    0.874
# 2      0.101     0.056    0.843
# 3      0.052     0.018    0.931
# 4      0.068     0.035    0.897
# 5      0.125     0.047    0.828
# 6      0.129     0.057    0.815
# 7      0.127     0.049    0.824
# 8      0.120     0.047    0.833
# 9      0.123     0.054    0.823
# 10     0.100     0.046    0.855
# 11     0.092     0.028    0.880
# 12     0.082     0.085    0.834
# 13     0.109     0.085    0.805
# 14     0.126     0.072    0.802
# 15     0.120     0.047    0.834
# 16     0.066     0.047    0.887
# 17     0.115     0.053    0.832
# 18     0.093     0.036    0.872
# 19     0.069     0.034    0.897
# 20     0.084     0.013    0.902
# 21     0.082     0.058    0.860
# 22     0.045     0.036    0.919
# 23     0.069     0.070    0.861
# 24     0.109     0.083    0.808
# 25     0.107     0.040    0.853
# 26     0.075     0.034    0.890
# 27     0.070     0.116    0.814
# 28     0.092     0.080    0.828
# 29     0.054     0.052    0.894
